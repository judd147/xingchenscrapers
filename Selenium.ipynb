# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.service import Service
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.wait import WebDriverWait
import time

def strip_parent(string):
    return string.split('(')[1].split(')')[0]

# %%
#https://developer.microsoft.com/en-us/microsoft-edge/tools/webdriver/
driver_path = r'D:\edgedriver_win64\msedgedriver.exe'
driver = webdriver.Edge(service=Service(executable_path=driver_path))
driver.implicitly_wait(10)
driver.get("https://www.sofascore.com/")

# %%
showodds = driver.find_element(By.CLASS_NAME,'slider')
showodds.click()

# %%
#数据存储
#FIXME 1.解决划动问题 2.如何根据数据库缺盘口的比赛寻找sofascore比赛
matches = driver.find_elements(By.CLASS_NAME,'sc-hKwDye.LFQYO.sc-9199a964-1.bnnDyH')
print('共{}场比赛'.format(len(matches)))
#for i in range(0,12):
for match in matches:
    match.click()
    time.sleep(2)
    handicap = driver.find_elements(By.CLASS_NAME,'sc-egiyK.bPBNjz')
    print('比赛：', handicap[0].text.split(')')[1]+'-'+handicap[1].text.split(')')[1])
    print('盘口：', strip_parent(handicap[0].text.split(' ')[0]))
    
    value = driver.find_elements(By.CLASS_NAME,'sc-egiyK.iJPpi')
    try:
        print(value[0].text,':',value[2].text)
        print(value[1].text,':',value[3].text)
    except:
        pass
    time.sleep(2)
# Out:
# 共12场比赛
# 比赛：  Melbourne Victory- Melbourne City
# 盘口： +0.75
# 比赛：  Everton- Crystal Palace
# 盘口： 0
# Everton : 1.78
# Crystal Palace : 2.13
# 比赛：  Manchester City- Brighton & Hove Albion
# 盘口： -1.75
# Man City : 1.94
# Brighton : 1.96
# 比赛：  Rayo Vallecano- Cádiz CF
# 盘口： -0.75
# Rayo Vallecano : 2.09
# Cádiz : 1.81
# 比赛：  Real Valladolid- Real Sociedad
# 盘口： 0.25
# Valladolid : 2.10
# Real Sociedad : 1.80
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-d1c01cb8c7f6> in <module>
#       8     time.sleep(2)
#       9     handicap = driver.find_elements(By.CLASS_NAME,'sc-egiyK.bPBNjz')
# ---> 10     print('比赛：', handicap[0].text.split(')')[1]+'-'+handicap[1].text.split(')')[1])
#      11     print('盘口：', strip_parent(handicap[0].text.split(' ')[0]))
#      12
#
# IndexError: list index out of range

# %%
handicap = driver.find_elements(By.CLASS_NAME,'sc-egiyK.bPBNjz')
for item in handicap:
    print(item.text)
    print('---')
value = driver.find_elements(By.CLASS_NAME,'sc-egiyK.iJPpi')
for item in value:
    print(item.text)
    print('---')
# Out:
# (0) Everton
# ---
# (-0) Crystal Palace
# ---
# Everton
# ---
# Crystal Palace
# ---
# 1.84
# ---
# 2.06
# ---
